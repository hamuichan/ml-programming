# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. 환경 설정 및 데이터 준비

# %% [markdown]
# ## 1.1 라이브러리 임포트

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, LSTM, GRU, concatenate, Bidirectional, GlobalAveragePooling1D
)
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ## 1.2 데이터 로드 헬퍼 함수 정의

# %%
def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %% [markdown]
# ## 1.3 데이터 로드 및 검증 세트 분리

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)
X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
# 3D 데이터를 스케일링하기 위해 (samples, timesteps, features) -> (samples * timesteps, features) 2D로 변환
n_features = X_train.shape[2]
X_train_2d = X_train.reshape(-1, n_features)
X_val_2d = X_val.reshape(-1, n_features)
testX_2d = testX.reshape(-1, n_features)

# %%
# Train 데이터 기준으로 스케일러 피팅
scaler = StandardScaler()
X_train_scaled_2d = scaler.fit_transform(X_train_2d)
X_val_scaled_2d = scaler.transform(X_val_2d)
testX_scaled_2d = scaler.transform(testX_2d)

# %%
# 다시 3D (samples, timesteps, features) 형태로 복원
X_train_scaled = X_train_scaled_2d.reshape(X_train.shape)
X_val_scaled = X_val_scaled_2d.reshape(X_val.shape)
testX_scaled = testX_scaled_2d.reshape(testX.shape)

# %%
print("Scaling completed. Scaled Train Shape:", X_train_scaled.shape)
# Out:
# Scaling completed. Scaled Train Shape: (5881, 128, 9)

# %% [markdown]
# # 2. 모델 정의

# %% [markdown]
# ## 2.1 모델 파라미터 설정

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
# 공통 학습 파라미터
EPOCHS = 100
BATCH_SIZE = 64

# 입력 형태 정의
input_shape = (n_timesteps, n_features)

# %% [markdown]
# ## 2.2 CNN + LSTM 모델 정의

# %%
def build_cnn_lstm_model():
    reg = l2(1e-4) # L2 규제 인스턴스

    model = Sequential([
        Input(shape=input_shape, name="Input_CNN_LSTM"),

        # 1. CNN 특징 추출기
        # [수정] padding='same' 추가, MaxPooling1D 제거
        Conv1D(filters=128, kernel_size=3, activation='relu', kernel_regularizer=reg, padding='same'),
        Dropout(0.3),

        # [NEW] Conv1D 레이어 추가 (특징 추출 강화)
        Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=reg, padding='same'),
        Dropout(0.3),

        # 2. 시퀀스 문맥 학습기
        # CNN이 추출한 특징 시퀀스 (batch, 128, 64)를 Bi-LSTM으로 학습
        Bidirectional(
            LSTM(100, return_sequences=True, kernel_regularizer=reg),
            name="Bi-LSTM"
        ),
        Dropout(0.3),

        # 3. 시퀀스 정보 압축
        GlobalAveragePooling1D(name="GAP"),

        # 4. 분류기
        Dense(128, activation='relu', kernel_regularizer=reg),
        Dropout(0.5),
        Dense(n_outputs, activation='softmax', name="Output")
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# # 3. 모델 빌드

# %%
model_cnn_lstm = build_cnn_lstm_model()

# %%
model_cnn_lstm.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)               │ (None, 128, 128)       │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 128, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Bi-LSTM (Bidirectional)         │ (None, 128, 200)       │       132,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128, 200)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ GAP (GlobalAveragePooling1D)    │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 186,726 (729.40 KB)
#  Trainable params: 186,726 (729.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 4. 모델 학습

# %%
# Callbacks 정의
# 15 Epochs 동안 val_loss가 개선되지 않으면 학습 중단 및 최적 가중치 복원
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
# 5 Epochs 동안 val_loss가 개선되지 않으면 학습률을 0.2배로 감소
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# %%
history = model_cnn_lstm.fit(
    X_train_scaled, # 스케일링된 데이터
    y_train_one_hot,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val_scaled, y_val_one_hot), # 스케일링된 데이터
    verbose=2,
    callbacks=callbacks # 콜백 적용
)
# Out:
# Epoch 1/100
# 92/92 - 6s - 70ms/step - accuracy: 0.7774 - loss: 0.6317 - val_accuracy: 0.9137 - val_loss: 0.2825 - learning_rate: 1.0000e-03
# Epoch 2/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9359 - loss: 0.2229 - val_accuracy: 0.9409 - val_loss: 0.1803 - learning_rate: 1.0000e-03
# Epoch 3/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9420 - loss: 0.1969 - val_accuracy: 0.9463 - val_loss: 0.1794 - learning_rate: 1.0000e-03
# Epoch 4/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9463 - loss: 0.1740 - val_accuracy: 0.9497 - val_loss: 0.1596 - learning_rate: 1.0000e-03
# Epoch 5/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9485 - loss: 0.1658 - val_accuracy: 0.9422 - val_loss: 0.1978 - learning_rate: 1.0000e-03
# Epoch 6/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9515 - loss: 0.1685 - val_accuracy: 0.9517 - val_loss: 0.1593 - learning_rate: 1.0000e-03
# Epoch 7/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9531 - loss: 0.1622 - val_accuracy: 0.9470 - val_loss: 0.1539 - learning_rate: 1.0000e-03
# Epoch 8/100
# 92/92 - 3s - 31ms/step - accuracy: 0.9537 - loss: 0.1551 - val_accuracy: 0.9517 - val_loss: 0.1528 - learning_rate: 1.0000e-03
# Epoch 9/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9551 - loss: 0.1481 - val_accuracy: 0.9123 - val_loss: 0.2905 - learning_rate: 1.0000e-03
# Epoch 10/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9548 - loss: 0.1502 - val_accuracy: 0.9545 - val_loss: 0.1421 - learning_rate: 1.0000e-03
# Epoch 11/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9609 - loss: 0.1303 - val_accuracy: 0.9551 - val_loss: 0.1386 - learning_rate: 1.0000e-03
# Epoch 12/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9631 - loss: 0.1262 - val_accuracy: 0.9504 - val_loss: 0.1443 - learning_rate: 1.0000e-03
# Epoch 13/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9602 - loss: 0.1311 - val_accuracy: 0.9558 - val_loss: 0.1353 - learning_rate: 1.0000e-03
# Epoch 14/100
# 92/92 - 3s - 35ms/step - accuracy: 0.9575 - loss: 0.1322 - val_accuracy: 0.9504 - val_loss: 0.1581 - learning_rate: 1.0000e-03
# Epoch 15/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9607 - loss: 0.1287 - val_accuracy: 0.9585 - val_loss: 0.1214 - learning_rate: 1.0000e-03
# Epoch 16/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9595 - loss: 0.1336 - val_accuracy: 0.9517 - val_loss: 0.1266 - learning_rate: 1.0000e-03
# Epoch 17/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9626 - loss: 0.1164 - val_accuracy: 0.9558 - val_loss: 0.1272 - learning_rate: 1.0000e-03
# Epoch 18/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9565 - loss: 0.1309 - val_accuracy: 0.9558 - val_loss: 0.1188 - learning_rate: 1.0000e-03
# Epoch 19/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9626 - loss: 0.1150 - val_accuracy: 0.9565 - val_loss: 0.1255 - learning_rate: 1.0000e-03
# Epoch 20/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9646 - loss: 0.1134 - val_accuracy: 0.9565 - val_loss: 0.1108 - learning_rate: 1.0000e-03
# Epoch 21/100
# 92/92 - 2s - 26ms/step - accuracy: 0.9629 - loss: 0.1049 - val_accuracy: 0.9599 - val_loss: 0.0988 - learning_rate: 1.0000e-03
# Epoch 22/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9626 - loss: 0.1033 - val_accuracy: 0.9633 - val_loss: 0.1009 - learning_rate: 1.0000e-03
# Epoch 23/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9636 - loss: 0.0998 - val_accuracy: 0.9592 - val_loss: 0.1018 - learning_rate: 1.0000e-03
# Epoch 24/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9633 - loss: 0.1036 - val_accuracy: 0.9626 - val_loss: 0.0975 - learning_rate: 1.0000e-03
# Epoch 25/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9646 - loss: 0.0926 - val_accuracy: 0.9524 - val_loss: 0.1152 - learning_rate: 1.0000e-03
# Epoch 26/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9641 - loss: 0.0965 - val_accuracy: 0.9592 - val_loss: 0.1021 - learning_rate: 1.0000e-03
# Epoch 27/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9592 - loss: 0.1223 - val_accuracy: 0.9538 - val_loss: 0.1174 - learning_rate: 1.0000e-03
# Epoch 28/100
# 92/92 - 2s - 26ms/step - accuracy: 0.9648 - loss: 0.0982 - val_accuracy: 0.9646 - val_loss: 0.0906 - learning_rate: 1.0000e-03
# Epoch 29/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9619 - loss: 0.0995 - val_accuracy: 0.9640 - val_loss: 0.1073 - learning_rate: 1.0000e-03
# Epoch 30/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9640 - loss: 0.0960 - val_accuracy: 0.9721 - val_loss: 0.0896 - learning_rate: 1.0000e-03
# Epoch 31/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9607 - loss: 0.1021 - val_accuracy: 0.9613 - val_loss: 0.1073 - learning_rate: 1.0000e-03
# Epoch 32/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9633 - loss: 0.0980 - val_accuracy: 0.9613 - val_loss: 0.0974 - learning_rate: 1.0000e-03
# Epoch 33/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9619 - loss: 0.1072 - val_accuracy: 0.9708 - val_loss: 0.0895 - learning_rate: 1.0000e-03
# Epoch 34/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9653 - loss: 0.0907 - val_accuracy: 0.9667 - val_loss: 0.0824 - learning_rate: 1.0000e-03
# Epoch 35/100
# 92/92 - 2s - 26ms/step - accuracy: 0.9685 - loss: 0.0857 - val_accuracy: 0.9687 - val_loss: 0.0815 - learning_rate: 1.0000e-03
# Epoch 36/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9694 - loss: 0.0816 - val_accuracy: 0.9714 - val_loss: 0.0806 - learning_rate: 1.0000e-03
# Epoch 37/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9696 - loss: 0.0860 - val_accuracy: 0.9701 - val_loss: 0.0811 - learning_rate: 1.0000e-03
# Epoch 38/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9687 - loss: 0.0805 - val_accuracy: 0.9660 - val_loss: 0.0902 - learning_rate: 1.0000e-03
# Epoch 39/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9694 - loss: 0.0816 - val_accuracy: 0.9721 - val_loss: 0.0783 - learning_rate: 1.0000e-03
# Epoch 40/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9665 - loss: 0.0975 - val_accuracy: 0.9511 - val_loss: 0.1571 - learning_rate: 1.0000e-03
# Epoch 41/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9623 - loss: 0.1132 - val_accuracy: 0.9701 - val_loss: 0.0822 - learning_rate: 1.0000e-03
# Epoch 42/100
# 92/92 - 2s - 24ms/step - accuracy: 0.9711 - loss: 0.0837 - val_accuracy: 0.9680 - val_loss: 0.0871 - learning_rate: 1.0000e-03
# Epoch 43/100
# 92/92 - 2s - 23ms/step - accuracy: 0.9745 - loss: 0.0758 - val_accuracy: 0.9803 - val_loss: 0.0765 - learning_rate: 1.0000e-03
# Epoch 44/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9702 - loss: 0.0849 - val_accuracy: 0.9674 - val_loss: 0.0848 - learning_rate: 1.0000e-03
# Epoch 45/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9721 - loss: 0.0813 - val_accuracy: 0.9728 - val_loss: 0.0816 - learning_rate: 1.0000e-03
# Epoch 46/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9752 - loss: 0.0740 - val_accuracy: 0.9701 - val_loss: 0.0887 - learning_rate: 1.0000e-03
# Epoch 47/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9736 - loss: 0.0780 - val_accuracy: 0.9776 - val_loss: 0.0721 - learning_rate: 1.0000e-03
# Epoch 48/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9757 - loss: 0.0732 - val_accuracy: 0.9694 - val_loss: 0.0767 - learning_rate: 1.0000e-03
# Epoch 49/100
# 92/92 - 2s - 26ms/step - accuracy: 0.9777 - loss: 0.0739 - val_accuracy: 0.9687 - val_loss: 0.0807 - learning_rate: 1.0000e-03
# Epoch 50/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9757 - loss: 0.0723 - val_accuracy: 0.9762 - val_loss: 0.0730 - learning_rate: 1.0000e-03
# Epoch 51/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9752 - loss: 0.0717 - val_accuracy: 0.9769 - val_loss: 0.0739 - learning_rate: 1.0000e-03
# Epoch 52/100
# 92/92 - 3s - 27ms/step - accuracy: 0.9753 - loss: 0.0752 - val_accuracy: 0.9742 - val_loss: 0.0787 - learning_rate: 1.0000e-03
# Epoch 53/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9762 - loss: 0.0663 - val_accuracy: 0.9762 - val_loss: 0.0684 - learning_rate: 2.0000e-04
# Epoch 54/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9810 - loss: 0.0602 - val_accuracy: 0.9810 - val_loss: 0.0635 - learning_rate: 2.0000e-04
# Epoch 55/100
# 92/92 - 2s - 24ms/step - accuracy: 0.9816 - loss: 0.0572 - val_accuracy: 0.9823 - val_loss: 0.0636 - learning_rate: 2.0000e-04
# Epoch 56/100
# 92/92 - 2s - 23ms/step - accuracy: 0.9833 - loss: 0.0540 - val_accuracy: 0.9776 - val_loss: 0.0635 - learning_rate: 2.0000e-04
# Epoch 57/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9837 - loss: 0.0552 - val_accuracy: 0.9837 - val_loss: 0.0606 - learning_rate: 2.0000e-04
# Epoch 58/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9847 - loss: 0.0530 - val_accuracy: 0.9837 - val_loss: 0.0600 - learning_rate: 2.0000e-04
# Epoch 59/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9859 - loss: 0.0507 - val_accuracy: 0.9803 - val_loss: 0.0659 - learning_rate: 2.0000e-04
# Epoch 60/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9849 - loss: 0.0526 - val_accuracy: 0.9810 - val_loss: 0.0608 - learning_rate: 2.0000e-04
# Epoch 61/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9861 - loss: 0.0501 - val_accuracy: 0.9803 - val_loss: 0.0580 - learning_rate: 2.0000e-04
# Epoch 62/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9854 - loss: 0.0484 - val_accuracy: 0.9776 - val_loss: 0.0682 - learning_rate: 2.0000e-04
# Epoch 63/100
# 92/92 - 2s - 24ms/step - accuracy: 0.9821 - loss: 0.0617 - val_accuracy: 0.9823 - val_loss: 0.0681 - learning_rate: 2.0000e-04
# Epoch 64/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9854 - loss: 0.0509 - val_accuracy: 0.9796 - val_loss: 0.0569 - learning_rate: 2.0000e-04
# Epoch 65/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9857 - loss: 0.0506 - val_accuracy: 0.9816 - val_loss: 0.0593 - learning_rate: 2.0000e-04
# Epoch 66/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9874 - loss: 0.0471 - val_accuracy: 0.9837 - val_loss: 0.0551 - learning_rate: 2.0000e-04
# Epoch 67/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9874 - loss: 0.0481 - val_accuracy: 0.9837 - val_loss: 0.0606 - learning_rate: 2.0000e-04
# Epoch 68/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9842 - loss: 0.0511 - val_accuracy: 0.9742 - val_loss: 0.0625 - learning_rate: 2.0000e-04
# Epoch 69/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9837 - loss: 0.0520 - val_accuracy: 0.9721 - val_loss: 0.0704 - learning_rate: 2.0000e-04
# Epoch 70/100
# 92/92 - 2s - 25ms/step - accuracy: 0.9825 - loss: 0.0533 - val_accuracy: 0.9810 - val_loss: 0.0612 - learning_rate: 2.0000e-04
# Epoch 71/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9862 - loss: 0.0502 - val_accuracy: 0.9803 - val_loss: 0.0580 - learning_rate: 2.0000e-04
# Epoch 72/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9864 - loss: 0.0476 - val_accuracy: 0.9789 - val_loss: 0.0582 - learning_rate: 4.0000e-05
# Epoch 73/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9883 - loss: 0.0448 - val_accuracy: 0.9803 - val_loss: 0.0599 - learning_rate: 4.0000e-05
# Epoch 74/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9864 - loss: 0.0450 - val_accuracy: 0.9803 - val_loss: 0.0566 - learning_rate: 4.0000e-05
# Epoch 75/100
# 92/92 - 2s - 19ms/step - accuracy: 0.9889 - loss: 0.0447 - val_accuracy: 0.9816 - val_loss: 0.0597 - learning_rate: 4.0000e-05
# Epoch 76/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9889 - loss: 0.0432 - val_accuracy: 0.9837 - val_loss: 0.0591 - learning_rate: 4.0000e-05
# Epoch 77/100
# 92/92 - 2s - 25ms/step - accuracy: 0.9900 - loss: 0.0422 - val_accuracy: 0.9810 - val_loss: 0.0583 - learning_rate: 8.0000e-06
# Epoch 78/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9895 - loss: 0.0423 - val_accuracy: 0.9823 - val_loss: 0.0588 - learning_rate: 8.0000e-06
# Epoch 79/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9905 - loss: 0.0428 - val_accuracy: 0.9837 - val_loss: 0.0592 - learning_rate: 8.0000e-06
# Epoch 80/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9879 - loss: 0.0436 - val_accuracy: 0.9830 - val_loss: 0.0591 - learning_rate: 8.0000e-06
# Epoch 81/100
# 92/92 - 2s - 18ms/step - accuracy: 0.9901 - loss: 0.0424 - val_accuracy: 0.9830 - val_loss: 0.0582 - learning_rate: 8.0000e-06

# %% [markdown]
# # 4. 결과 분석 및 평가

# %% [markdown]
# ## 4.1 학습 과정 시각화 (Loss & Accuracy)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('CNN + LSTM Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('CNN + LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2 테스트 세트 평가 (Confusion Matrix)

# %%
pred_probs = model_cnn_lstm.predict(testX_scaled)
pred_classes = np.argmax(pred_probs, axis=-1)

print(f"Accuracy: {accuracy_score(testy, pred_classes):.4f}")
print("\nClassification Report:")
print(classification_report(testy, pred_classes))

cm = confusion_matrix(testy, pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('CNN + LSTM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9067
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       496
#            1       0.97      0.91      0.94       471
#            2       0.91      0.98      0.95       420
#            3       0.80      0.76      0.78       491
#            4       0.81      0.83      0.82       532
#            5       1.00      1.00      1.00       537
#
#     accuracy                           0.91      2947
#    macro avg       0.91      0.91      0.91      2947
# weighted avg       0.91      0.91      0.91      2947
