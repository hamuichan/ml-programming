# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. 환경 설정 및 데이터 준비

# %% [markdown]
# ## 1.1 라이브러리 임포트

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, LSTM, GRU, concatenate, Bidirectional, GlobalAveragePooling1D
)
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# %% [markdown]
# ## 1.2 데이터 로드 헬퍼 함수 정의

# %%
def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %% [markdown]
# ## 1.3 데이터 로드 및 검증 세트 분리

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)
X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
# 3D 데이터를 스케일링하기 위해 (samples, timesteps, features) -> (samples * timesteps, features) 2D로 변환
n_features = X_train.shape[2]
X_train_2d = X_train.reshape(-1, n_features)
X_val_2d = X_val.reshape(-1, n_features)
testX_2d = testX.reshape(-1, n_features)

# %%
# Train 데이터 기준으로 스케일러 피팅
scaler = StandardScaler()
X_train_scaled_2d = scaler.fit_transform(X_train_2d)
X_val_scaled_2d = scaler.transform(X_val_2d)
testX_scaled_2d = scaler.transform(testX_2d)

# %%
# 다시 3D (samples, timesteps, features) 형태로 복원
X_train_scaled = X_train_scaled_2d.reshape(X_train.shape)
X_val_scaled = X_val_scaled_2d.reshape(X_val.shape)
testX_scaled = testX_scaled_2d.reshape(testX.shape)

# %%
print("Scaling completed. Scaled Train Shape:", X_train_scaled.shape)
# Out:
# Scaling completed. Scaled Train Shape: (5881, 128, 9)

# %% [markdown]
# # 2. 모델 정의

# %% [markdown]
# ## 2.1 모델 파라미터 설정

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
# 공통 학습 파라미터
EPOCHS = 30
BATCH_SIZE = 32

# 입력 형태 정의
input_shape = (n_timesteps, n_features)

# %% [markdown]
# ## 2.2 CNN + GRU 모델 정의

# %%
def build_cnn_gru_model():
    reg = l2(1e-4) # L2 규제 인스턴스

    model = Sequential([
        Input(shape=input_shape, name="Input_CNN_GRU"),

        # 1. CNN 특징 추출기
        Conv1D(filters=128, kernel_size=3, activation='relu', kernel_regularizer=reg, padding='same'),
        Dropout(0.3),
        Conv1D(filters=64, kernel_size=3, activation='relu', kernel_regularizer=reg, padding='same'),
        Dropout(0.3),

        # 2. 시퀀스 문맥 학습기 (LSTM -> GRU로 변경)
        Bidirectional(
            GRU(100, return_sequences=True, kernel_regularizer=reg), # [수정]
            name="Bi-GRU"
        ),
        Dropout(0.3),

        # 3. 시퀀스 정보 압축
        GlobalAveragePooling1D(name="GAP"),

        # 4. 분류기
        Dense(128, activation='relu', kernel_regularizer=reg),
        Dropout(0.5),
        Dense(n_outputs, activation='softmax', name="Output")
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# # 3. 모델 빌드

# %%
model_cnn_gru = build_cnn_gru_model()

# %%
model_cnn_gru.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 128, 128)       │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 128, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Bi-GRU (Bidirectional)          │ (None, 128, 200)       │        99,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128, 200)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ GAP (GlobalAveragePooling1D)    │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 154,326 (602.84 KB)
#  Trainable params: 154,326 (602.84 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 4. 모델 학습

# %%
# Callbacks 정의
# 15 Epochs 동안 val_loss가 개선되지 않으면 학습 중단 및 최적 가중치 복원
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
# 5 Epochs 동안 val_loss가 개선되지 않으면 학습률을 0.2배로 감소
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# %%
history = model_cnn_gru.fit(
    X_train_scaled, # 스케일링된 데이터
    y_train_one_hot,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val_scaled, y_val_one_hot), # 스케일링된 데이터
    verbose=2,
    callbacks=callbacks # 콜백 적용
)
# Out:
# Epoch 1/30
# 184/184 - 11s - 59ms/step - accuracy: 0.8247 - loss: 0.4961 - val_accuracy: 0.9422 - val_loss: 0.1937 - learning_rate: 1.0000e-03
# Epoch 2/30
# 184/184 - 3s - 16ms/step - accuracy: 0.9396 - loss: 0.2008 - val_accuracy: 0.9449 - val_loss: 0.1677 - learning_rate: 1.0000e-03
# Epoch 3/30
# 184/184 - 5s - 28ms/step - accuracy: 0.9444 - loss: 0.1855 - val_accuracy: 0.9361 - val_loss: 0.1711 - learning_rate: 1.0000e-03
# Epoch 4/30
# 184/184 - 5s - 28ms/step - accuracy: 0.9514 - loss: 0.1502 - val_accuracy: 0.9551 - val_loss: 0.1466 - learning_rate: 1.0000e-03
# Epoch 5/30
# 184/184 - 3s - 18ms/step - accuracy: 0.9539 - loss: 0.1438 - val_accuracy: 0.9531 - val_loss: 0.1384 - learning_rate: 1.0000e-03
# Epoch 6/30
# 184/184 - 5s - 25ms/step - accuracy: 0.9510 - loss: 0.1546 - val_accuracy: 0.9565 - val_loss: 0.1453 - learning_rate: 1.0000e-03
# Epoch 7/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9541 - loss: 0.1312 - val_accuracy: 0.9565 - val_loss: 0.1441 - learning_rate: 1.0000e-03
# Epoch 8/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9582 - loss: 0.1287 - val_accuracy: 0.9551 - val_loss: 0.1325 - learning_rate: 1.0000e-03
# Epoch 9/30
# 184/184 - 4s - 20ms/step - accuracy: 0.9577 - loss: 0.1211 - val_accuracy: 0.9579 - val_loss: 0.1199 - learning_rate: 1.0000e-03
# Epoch 10/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9534 - loss: 0.1370 - val_accuracy: 0.9524 - val_loss: 0.1314 - learning_rate: 1.0000e-03
# Epoch 11/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9524 - loss: 0.1372 - val_accuracy: 0.9606 - val_loss: 0.1097 - learning_rate: 1.0000e-03
# Epoch 12/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9597 - loss: 0.1143 - val_accuracy: 0.9613 - val_loss: 0.1070 - learning_rate: 1.0000e-03
# Epoch 13/30
# 184/184 - 6s - 32ms/step - accuracy: 0.9607 - loss: 0.1100 - val_accuracy: 0.9633 - val_loss: 0.1034 - learning_rate: 1.0000e-03
# Epoch 14/30
# 184/184 - 3s - 17ms/step - accuracy: 0.9616 - loss: 0.1028 - val_accuracy: 0.9613 - val_loss: 0.0987 - learning_rate: 1.0000e-03
# Epoch 15/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9643 - loss: 0.1063 - val_accuracy: 0.9626 - val_loss: 0.1006 - learning_rate: 1.0000e-03
# Epoch 16/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9624 - loss: 0.1013 - val_accuracy: 0.9606 - val_loss: 0.1065 - learning_rate: 1.0000e-03
# Epoch 17/30
# 184/184 - 4s - 23ms/step - accuracy: 0.9658 - loss: 0.0974 - val_accuracy: 0.9646 - val_loss: 0.1008 - learning_rate: 1.0000e-03
# Epoch 18/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9609 - loss: 0.1171 - val_accuracy: 0.9640 - val_loss: 0.1004 - learning_rate: 1.0000e-03
# Epoch 19/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9626 - loss: 0.1083 - val_accuracy: 0.9633 - val_loss: 0.0958 - learning_rate: 1.0000e-03
# Epoch 20/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9667 - loss: 0.0960 - val_accuracy: 0.9653 - val_loss: 0.0999 - learning_rate: 1.0000e-03
# Epoch 21/30
# 184/184 - 4s - 21ms/step - accuracy: 0.9684 - loss: 0.0938 - val_accuracy: 0.9728 - val_loss: 0.0905 - learning_rate: 1.0000e-03
# Epoch 22/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9725 - loss: 0.0852 - val_accuracy: 0.9708 - val_loss: 0.0863 - learning_rate: 1.0000e-03
# Epoch 23/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9704 - loss: 0.0830 - val_accuracy: 0.9708 - val_loss: 0.0818 - learning_rate: 1.0000e-03
# Epoch 24/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9760 - loss: 0.0751 - val_accuracy: 0.9769 - val_loss: 0.0786 - learning_rate: 1.0000e-03
# Epoch 25/30
# 184/184 - 3s - 18ms/step - accuracy: 0.9728 - loss: 0.0819 - val_accuracy: 0.9789 - val_loss: 0.0753 - learning_rate: 1.0000e-03
# Epoch 26/30
# 184/184 - 3s - 17ms/step - accuracy: 0.9738 - loss: 0.0829 - val_accuracy: 0.9755 - val_loss: 0.0782 - learning_rate: 1.0000e-03
# Epoch 27/30
# 184/184 - 3s - 17ms/step - accuracy: 0.9738 - loss: 0.0819 - val_accuracy: 0.9714 - val_loss: 0.1028 - learning_rate: 1.0000e-03
# Epoch 28/30
# 184/184 - 3s - 15ms/step - accuracy: 0.9750 - loss: 0.0808 - val_accuracy: 0.9701 - val_loss: 0.0765 - learning_rate: 1.0000e-03
# Epoch 29/30
# 184/184 - 3s - 17ms/step - accuracy: 0.9752 - loss: 0.0742 - val_accuracy: 0.9789 - val_loss: 0.0747 - learning_rate: 1.0000e-03
# Epoch 30/30
# 184/184 - 3s - 19ms/step - accuracy: 0.9794 - loss: 0.0709 - val_accuracy: 0.9803 - val_loss: 0.0699 - learning_rate: 1.0000e-03

# %% [markdown]
# # 4. 결과 분석 및 평가

# %% [markdown]
# ## 4.1 학습 과정 시각화 (Loss & Accuracy)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('CNN + GRU Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('CNN + GRU Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2 테스트 세트 평가 (Confusion Matrix)

# %%
pred_probs = model_cnn_gru.predict(testX_scaled)
pred_classes = np.argmax(pred_probs, axis=-1)

print(f"Accuracy: {accuracy_score(testy, pred_classes):.4f}")
print("\nClassification Report:")
print(classification_report(testy, pred_classes))

cm = confusion_matrix(testy, pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('CNN + GRU Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Accuracy: 0.9318
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       496
#            1       0.96      0.95      0.96       471
#            2       0.94      0.96      0.95       420
#            3       0.82      0.85      0.84       491
#            4       0.88      0.83      0.85       532
#            5       1.00      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.93      0.93      0.93      2947
# weighted avg       0.93      0.93      0.93      2947
