# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. 환경 설정 및 데이터 준비

# %% [markdown]
# ## 1.1 라이브러리 임포트

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, LSTM, GRU, concatenate,
    GlobalAveragePooling1D,
    Add, Activation, LayerNormalization,
    MultiHeadAttention
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.2 데이터 로드 헬퍼 함수 정의

# %%
def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %% [markdown]
# ## 1.3 데이터 로드 및 검증 세트 분리

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)
X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
# 3D 데이터를 스케일링하기 위해 (samples, timesteps, features) -> (samples * timesteps, features) 2D로 변환
n_features = X_train.shape[2]
X_train_2d = X_train.reshape(-1, n_features)
X_val_2d = X_val.reshape(-1, n_features)
testX_2d = testX.reshape(-1, n_features)

# %%
# Train 데이터 기준으로 스케일러 피팅
scaler = StandardScaler()
X_train_scaled_2d = scaler.fit_transform(X_train_2d)
X_val_scaled_2d = scaler.transform(X_val_2d)
testX_scaled_2d = scaler.transform(testX_2d)

# %%
# 다시 3D (samples, timesteps, features) 형태로 복원
X_train_scaled = X_train_scaled_2d.reshape(X_train.shape)
X_val_scaled = X_val_scaled_2d.reshape(X_val.shape)
testX_scaled = testX_scaled_2d.reshape(testX.shape)

# %%
print("Scaling completed. Scaled Train Shape:", X_train_scaled.shape)
# Out:
# Scaling completed. Scaled Train Shape: (5881, 128, 9)

# %% [markdown]
# # 2. 모델 정의

# %% [markdown]
# ## 2.1 모델 파라미터 설정

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
# 공통 학습 파라미터
EPOCHS = 100
BATCH_SIZE = 64

# 입력 형태 정의
input_shape = (n_timesteps, n_features)

# %% [markdown]
# ## 2.2 ResNet + Transformer 모델 정의

# %%
def res_block(x, filters, kernel_size=3, reg=l2(1e-4)):
    shortcut = x
    y = Conv1D(filters, kernel_size, padding='same', kernel_regularizer=reg)(x)
    y = LayerNormalization()(y)
    y = Activation('relu')(y)
    y = Conv1D(filters, kernel_size, padding='same', kernel_regularizer=reg)(y)
    y = LayerNormalization()(y)
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding='same', kernel_regularizer=reg)(shortcut)
        shortcut = LayerNormalization()(shortcut)
    y = Add()([shortcut, y])
    y = Activation('relu')(y)
    return y

# %%
def transformer_encoder_block(inputs, head_size, num_heads, ff_dim, dropout=0, reg=l2(1e-4)):
    x = LayerNormalization()(inputs)
    x = MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = Dropout(dropout)(x)
    res = Add()([x, inputs])
    x = LayerNormalization()(res)
    x = Conv1D(filters=ff_dim, kernel_size=1, activation='relu', kernel_regularizer=reg)(x)
    x = Dropout(dropout)(x)
    x = Conv1D(filters=inputs.shape[-1], kernel_size=1, kernel_regularizer=reg)(x)
    x = Add()([x, res])
    return x

# %%
def build_resnet_transformer_model():
    reg = l2(1e-4)
    inputs = Input(shape=input_shape)

    # 1. ResNet Feature Extractor (Stem)
    x = Conv1D(128, 3, padding='same', kernel_regularizer=reg)(inputs)
    x = LayerNormalization()(x)
    x = Activation('relu')(x)

    # ResNet 블록 (128 필터)
    x = res_block(x, 128, reg=reg)
    x = res_block(x, 128, reg=reg)

    x = MaxPooling1D(pool_size=2)(x)

    # 2. Transformer Encoder
    # 64개의 타임스텝을 가진 128차원 특징 벡터를 처리
    x = transformer_encoder_block(x, head_size=128, num_heads=4, ff_dim=256, dropout=0.3, reg=reg)
    x = transformer_encoder_block(x, head_size=128, num_heads=4, ff_dim=256, dropout=0.3, reg=reg)

    # 3. Classifier
    x = GlobalAveragePooling1D()(x) # (batch, 128)
    x = Dense(512, activation='relu', kernel_regularizer=reg)(x) # [수정] 256 -> 512
    x = Dropout(0.5)(x)
    outputs = Dense(n_outputs, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)

    optimizer = Adam(learning_rate=5e-4)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %% [markdown]
# # 3. 모델 빌드

# %%
model_hybrid = build_resnet_transformer_model()

# %%
model_hybrid.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 128, 128)  │      3,584 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ conv1d_9[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128)  │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 128, 128)  │     49,280 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ conv1d_10[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 128, 128)  │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 128, 128)  │     49,280 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ conv1d_11[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128, 128)  │          0 │ activation_5[0][… │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128, 128)  │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 128, 128)  │     49,280 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ conv1d_12[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 128, 128)  │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 128, 128)  │     49,280 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ conv1d_13[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 128, 128)  │          0 │ activation_7[0][… │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 128, 128)  │          0 │ add_7[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 64, 128)   │          0 │ activation_9[0][… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ max_pooling1d_1[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 128)   │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 128)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 64, 128)   │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 64, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 64, 256)   │          0 │ conv1d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 64, 128)   │     32,896 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 64, 128)   │          0 │ conv1d_15[0][0],  │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 128)   │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 64, 128)   │          0 │ dropout_11[0][0], │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 64, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 64, 256)   │          0 │ conv1d_16[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 64, 128)   │     32,896 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 64, 128)   │          0 │ conv1d_17[0][0],  │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ add_11[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 512)       │          0 │ dense_2[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 6)         │      3,078 │ dropout_13[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 931,590 (3.55 MB)
#  Trainable params: 931,590 (3.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 4. 모델 학습

# %%
# Callbacks 정의
# 15 Epochs 동안 val_loss가 개선되지 않으면 학습 중단 및 최적 가중치 복원
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
# 5 Epochs 동안 val_loss가 개선되지 않으면 학습률을 0.2배로 감소
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# %%
history = model_hybrid.fit(
    X_train_scaled,
    y_train_one_hot,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val_scaled, y_val_one_hot),
    verbose=2,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 92/92 - 48s - 524ms/step - accuracy: 0.8356 - loss: 0.5864 - val_accuracy: 0.9415 - val_loss: 0.2712 - learning_rate: 5.0000e-04
# Epoch 2/100
# 92/92 - 2s - 23ms/step - accuracy: 0.9478 - loss: 0.2725 - val_accuracy: 0.9361 - val_loss: 0.2843 - learning_rate: 5.0000e-04
# Epoch 3/100
# 92/92 - 2s - 26ms/step - accuracy: 0.9463 - loss: 0.2732 - val_accuracy: 0.9565 - val_loss: 0.2288 - learning_rate: 5.0000e-04
# Epoch 4/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9563 - loss: 0.2365 - val_accuracy: 0.9565 - val_loss: 0.2301 - learning_rate: 5.0000e-04
# Epoch 5/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9548 - loss: 0.2414 - val_accuracy: 0.9592 - val_loss: 0.2183 - learning_rate: 5.0000e-04
# Epoch 6/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9532 - loss: 0.2369 - val_accuracy: 0.9531 - val_loss: 0.2458 - learning_rate: 5.0000e-04
# Epoch 7/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9585 - loss: 0.2203 - val_accuracy: 0.9646 - val_loss: 0.2072 - learning_rate: 5.0000e-04
# Epoch 8/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9645 - loss: 0.2018 - val_accuracy: 0.9674 - val_loss: 0.1989 - learning_rate: 5.0000e-04
# Epoch 9/100
# 92/92 - 2s - 23ms/step - accuracy: 0.9650 - loss: 0.2012 - val_accuracy: 0.9585 - val_loss: 0.2125 - learning_rate: 5.0000e-04
# Epoch 10/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9680 - loss: 0.1957 - val_accuracy: 0.9613 - val_loss: 0.2011 - learning_rate: 5.0000e-04
# Epoch 11/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9653 - loss: 0.2028 - val_accuracy: 0.9619 - val_loss: 0.2225 - learning_rate: 5.0000e-04
# Epoch 12/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9682 - loss: 0.1896 - val_accuracy: 0.9694 - val_loss: 0.1930 - learning_rate: 5.0000e-04
# Epoch 13/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9718 - loss: 0.1846 - val_accuracy: 0.9714 - val_loss: 0.1858 - learning_rate: 5.0000e-04
# Epoch 14/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9767 - loss: 0.1721 - val_accuracy: 0.9708 - val_loss: 0.2109 - learning_rate: 5.0000e-04
# Epoch 15/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9711 - loss: 0.1875 - val_accuracy: 0.9803 - val_loss: 0.1589 - learning_rate: 5.0000e-04
# Epoch 16/100
# 92/92 - 2s - 23ms/step - accuracy: 0.9816 - loss: 0.1648 - val_accuracy: 0.9891 - val_loss: 0.1516 - learning_rate: 5.0000e-04
# Epoch 17/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9833 - loss: 0.1555 - val_accuracy: 0.9769 - val_loss: 0.1623 - learning_rate: 5.0000e-04
# Epoch 18/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9845 - loss: 0.1480 - val_accuracy: 0.9830 - val_loss: 0.1496 - learning_rate: 5.0000e-04
# Epoch 19/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9835 - loss: 0.1507 - val_accuracy: 0.9810 - val_loss: 0.1556 - learning_rate: 5.0000e-04
# Epoch 20/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9798 - loss: 0.1705 - val_accuracy: 0.9714 - val_loss: 0.1764 - learning_rate: 5.0000e-04
# Epoch 21/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9878 - loss: 0.1426 - val_accuracy: 0.9789 - val_loss: 0.1609 - learning_rate: 5.0000e-04
# Epoch 22/100
# 92/92 - 3s - 32ms/step - accuracy: 0.9862 - loss: 0.1374 - val_accuracy: 0.9830 - val_loss: 0.1496 - learning_rate: 5.0000e-04
# Epoch 23/100
# 92/92 - 2s - 27ms/step - accuracy: 0.9896 - loss: 0.1275 - val_accuracy: 0.9844 - val_loss: 0.1484 - learning_rate: 5.0000e-04
# Epoch 24/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9929 - loss: 0.1222 - val_accuracy: 0.9816 - val_loss: 0.1527 - learning_rate: 5.0000e-04
# Epoch 25/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9949 - loss: 0.1138 - val_accuracy: 0.9918 - val_loss: 0.1258 - learning_rate: 5.0000e-04
# Epoch 26/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9925 - loss: 0.1161 - val_accuracy: 0.9850 - val_loss: 0.1450 - learning_rate: 5.0000e-04
# Epoch 27/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9946 - loss: 0.1098 - val_accuracy: 0.9898 - val_loss: 0.1212 - learning_rate: 5.0000e-04
# Epoch 28/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9956 - loss: 0.1090 - val_accuracy: 0.9810 - val_loss: 0.1489 - learning_rate: 5.0000e-04
# Epoch 29/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9923 - loss: 0.1138 - val_accuracy: 0.9925 - val_loss: 0.1193 - learning_rate: 5.0000e-04
# Epoch 30/100
# 92/92 - 2s - 25ms/step - accuracy: 0.9940 - loss: 0.1095 - val_accuracy: 0.9864 - val_loss: 0.1350 - learning_rate: 5.0000e-04
# Epoch 31/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9913 - loss: 0.1137 - val_accuracy: 0.9912 - val_loss: 0.1095 - learning_rate: 5.0000e-04
# Epoch 32/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9823 - loss: 0.1436 - val_accuracy: 0.9748 - val_loss: 0.1575 - learning_rate: 5.0000e-04
# Epoch 33/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9939 - loss: 0.1039 - val_accuracy: 0.9830 - val_loss: 0.1345 - learning_rate: 5.0000e-04
# Epoch 34/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9929 - loss: 0.1010 - val_accuracy: 0.9864 - val_loss: 0.1308 - learning_rate: 5.0000e-04
# Epoch 35/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9947 - loss: 0.0971 - val_accuracy: 0.9898 - val_loss: 0.1091 - learning_rate: 5.0000e-04
# Epoch 36/100
# 92/92 - 2s - 22ms/step - accuracy: 0.9964 - loss: 0.0930 - val_accuracy: 0.9878 - val_loss: 0.1313 - learning_rate: 5.0000e-04
# Epoch 37/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9872 - loss: 0.1166 - val_accuracy: 0.9878 - val_loss: 0.1222 - learning_rate: 5.0000e-04
# Epoch 38/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9940 - loss: 0.0954 - val_accuracy: 0.9878 - val_loss: 0.1203 - learning_rate: 5.0000e-04
# Epoch 39/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9973 - loss: 0.0834 - val_accuracy: 0.9905 - val_loss: 0.1028 - learning_rate: 5.0000e-04
# Epoch 40/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9966 - loss: 0.0852 - val_accuracy: 0.9844 - val_loss: 0.1428 - learning_rate: 5.0000e-04
# Epoch 41/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9951 - loss: 0.0914 - val_accuracy: 0.9857 - val_loss: 0.1105 - learning_rate: 5.0000e-04
# Epoch 42/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9947 - loss: 0.0877 - val_accuracy: 0.9891 - val_loss: 0.1112 - learning_rate: 5.0000e-04
# Epoch 43/100
# 92/92 - 2s - 24ms/step - accuracy: 0.9957 - loss: 0.0814 - val_accuracy: 0.9891 - val_loss: 0.1162 - learning_rate: 5.0000e-04
# Epoch 44/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9934 - loss: 0.0877 - val_accuracy: 0.9830 - val_loss: 0.1152 - learning_rate: 5.0000e-04
# Epoch 45/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9976 - loss: 0.0747 - val_accuracy: 0.9891 - val_loss: 0.0946 - learning_rate: 1.0000e-04
# Epoch 46/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9998 - loss: 0.0693 - val_accuracy: 0.9912 - val_loss: 0.0930 - learning_rate: 1.0000e-04
# Epoch 47/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9998 - loss: 0.0681 - val_accuracy: 0.9912 - val_loss: 0.0929 - learning_rate: 1.0000e-04
# Epoch 48/100
# 92/92 - 2s - 20ms/step - accuracy: 0.9998 - loss: 0.0676 - val_accuracy: 0.9918 - val_loss: 0.0940 - learning_rate: 1.0000e-04
# Epoch 49/100
# 92/92 - 2s - 21ms/step - accuracy: 0.9998 - loss: 0.0668 - val_accuracy: 0.9912 - val_loss: 0.0953 - learning_rate: 1.0000e-04
# Epoch 50/100
# 92/92 - 2s - 22ms/step - accuracy: 1.0000 - loss: 0.0661 - val_accuracy: 0.9918 - val_loss: 0.0944 - learning_rate: 1.0000e-04
# Epoch 51/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0656 - val_accuracy: 0.9918 - val_loss: 0.0946 - learning_rate: 1.0000e-04
# Epoch 52/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0653 - val_accuracy: 0.9918 - val_loss: 0.0946 - learning_rate: 2.0000e-05
# Epoch 53/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0652 - val_accuracy: 0.9918 - val_loss: 0.0944 - learning_rate: 2.0000e-05
# Epoch 54/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 0.9918 - val_loss: 0.0943 - learning_rate: 2.0000e-05
# Epoch 55/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0650 - val_accuracy: 0.9918 - val_loss: 0.0944 - learning_rate: 2.0000e-05
# Epoch 56/100
# 92/92 - 2s - 23ms/step - accuracy: 1.0000 - loss: 0.0649 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 2.0000e-05
# Epoch 57/100
# 92/92 - 2s - 22ms/step - accuracy: 1.0000 - loss: 0.0648 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 4.0000e-06
# Epoch 58/100
# 92/92 - 2s - 26ms/step - accuracy: 1.0000 - loss: 0.0648 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 4.0000e-06
# Epoch 59/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 4.0000e-06
# Epoch 60/100
# 92/92 - 2s - 23ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 4.0000e-06
# Epoch 61/100
# 92/92 - 2s - 20ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 4.0000e-06
# Epoch 62/100
# 92/92 - 3s - 30ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.9925 - val_loss: 0.0943 - learning_rate: 1.0000e-06

# %% [markdown]
# # 4. 결과 분석 및 평가

# %% [markdown]
# ## 4.1 학습 과정 시각화 (Loss & Accuracy)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('ResNet+Transformer Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('ResNet+Transformer Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2 테스트 세트 평가 (Confusion Matrix)

# %%
pred_probs = model_hybrid.predict(testX_scaled)
pred_classes = np.argmax(pred_probs, axis=-1)

print(f"Accuracy: {accuracy_score(testy, pred_classes):.4f}")
print("\nClassification Report:")
print(classification_report(testy, pred_classes))

cm = confusion_matrix(testy, pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('ResNet+Transformer Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
# Accuracy: 0.9433
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       496
#            1       1.00      0.94      0.97       471
#            2       0.90      1.00      0.95       420
#            3       0.94      0.82      0.88       491
#            4       0.86      0.95      0.90       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.94      2947
#    macro avg       0.95      0.94      0.94      2947
# weighted avg       0.95      0.94      0.94      2947
