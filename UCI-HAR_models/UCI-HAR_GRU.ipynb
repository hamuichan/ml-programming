# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. 환경 설정 및 데이터 준비

# %% [markdown]
# ## 1.1 라이브러리 임포트

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, LSTM, GRU, concatenate,
    Bidirectional, GlobalAveragePooling1D
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.2 데이터 로드 헬퍼 함수 정의

# %%
def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values

# %%
# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# %%
# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

# %%
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/Colab Notebooks/machine-learning-programming/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %% [markdown]
# ## 1.3 데이터 로드 및 검증 세트 분리

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.2,random_state=100)
X_train.shape,X_val.shape,y_train_one_hot.shape,y_val_one_hot.shape,y_train.shape,y_val.shape
# Out:
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# /tmp/ipython-input-1098839523.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)
# ((5881, 128, 9), (1471, 128, 9), (5881, 6), (1471, 6), (5881, 1), (1471, 1))

# %%
# 3D 데이터를 스케일링하기 위해 (samples, timesteps, features) -> (samples * timesteps, features) 2D로 변환
n_features = X_train.shape[2]
X_train_2d = X_train.reshape(-1, n_features)
X_val_2d = X_val.reshape(-1, n_features)
testX_2d = testX.reshape(-1, n_features)

# %%
# Train 데이터 기준으로 스케일러 피팅
scaler = StandardScaler()
X_train_scaled_2d = scaler.fit_transform(X_train_2d)
X_val_scaled_2d = scaler.transform(X_val_2d)
testX_scaled_2d = scaler.transform(testX_2d)

# %%
# 다시 3D (samples, timesteps, features) 형태로 복원
X_train_scaled = X_train_scaled_2d.reshape(X_train.shape)
X_val_scaled = X_val_scaled_2d.reshape(X_val.shape)
testX_scaled = testX_scaled_2d.reshape(testX.shape)

# %%
print("Scaling completed. Scaled Train Shape:", X_train_scaled.shape)
# Out:
# Scaling completed. Scaled Train Shape: (5881, 128, 9)

# %% [markdown]
# # 2. 모델 정의

# %% [markdown]
# ## 2.1 모델 파라미터 설정

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]

# %%
# 공통 학습 파라미터
EPOCHS = 100
BATCH_SIZE = 64

# 입력 형태 정의
input_shape = (n_timesteps, n_features)

# %% [markdown]
# ## 2.2 GRU 모델 정의

# %%
def build_gru_model():
    reg = l2(1e-4) # L2 규제 인스턴스

    model = Sequential([
        Input(shape=input_shape, name="Input_GRU"),

        # Bi-GRU (cuDNN 가속을 위해 recurrent_dropout 제외)
        Bidirectional(
            GRU(100, return_sequences=True, kernel_regularizer=reg),
            name="Bi-GRU_1"
        ),
        Dropout(0.3),

        # 두 번째 Bi-GRU (전체 시퀀스 반환)
        Bidirectional(
            GRU(100, return_sequences=True, kernel_regularizer=reg),
            name="Bi-GRU_2"
        ),
        Dropout(0.3),

        # 모든 타임스텝의 정보를 평균내어 압축
        GlobalAveragePooling1D(name="GAP"),

        # 분류기
        Dense(128, activation='relu', kernel_regularizer=reg),
        Dropout(0.5),
        Dense(n_outputs, activation='softmax', name="Output")
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# # 3. 모델 빌드

# %%
model_gru = build_gru_model()

# %%
model_gru.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Bi-GRU_1 (Bidirectional)        │ (None, 128, 200)       │        66,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 200)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Bi-GRU_2 (Bidirectional)        │ (None, 128, 200)       │       181,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 200)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ GAP (GlobalAveragePooling1D)    │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 274,302 (1.05 MB)
#  Trainable params: 274,302 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 4. 모델 학습

# %%
# Callbacks 정의
# 15 Epochs 동안 val_loss가 개선되지 않으면 학습 중단 및 최적 가중치 복원
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
# 5 Epochs 동안 val_loss가 개선되지 않으면 학습률을 0.2배로 감소
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
callbacks = [early_stopping, reduce_lr]

# %%
history = model_gru.fit(
    X_train_scaled, # 스케일링된 데이터 사용
    y_train_one_hot,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val_scaled, y_val_one_hot), # 스케일링된 데이터 사용
    verbose=2,
    callbacks=callbacks # 콜백 적용
)
# Out:
# Epoch 1/100
# 92/92 - 11s - 118ms/step - accuracy: 0.7951 - loss: 0.6122 - val_accuracy: 0.9286 - val_loss: 0.2303 - learning_rate: 1.0000e-03
# Epoch 2/100
# 92/92 - 6s - 66ms/step - accuracy: 0.9398 - loss: 0.2129 - val_accuracy: 0.9436 - val_loss: 0.1837 - learning_rate: 1.0000e-03
# Epoch 3/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9463 - loss: 0.1869 - val_accuracy: 0.9490 - val_loss: 0.1720 - learning_rate: 1.0000e-03
# Epoch 4/100
# 92/92 - 3s - 34ms/step - accuracy: 0.9485 - loss: 0.1705 - val_accuracy: 0.9483 - val_loss: 0.1592 - learning_rate: 1.0000e-03
# Epoch 5/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9509 - loss: 0.1550 - val_accuracy: 0.9517 - val_loss: 0.1522 - learning_rate: 1.0000e-03
# Epoch 6/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9558 - loss: 0.1476 - val_accuracy: 0.9545 - val_loss: 0.1470 - learning_rate: 1.0000e-03
# Epoch 7/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9549 - loss: 0.1428 - val_accuracy: 0.9415 - val_loss: 0.1646 - learning_rate: 1.0000e-03
# Epoch 8/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9505 - loss: 0.1654 - val_accuracy: 0.9511 - val_loss: 0.1526 - learning_rate: 1.0000e-03
# Epoch 9/100
# 92/92 - 5s - 56ms/step - accuracy: 0.9493 - loss: 0.1734 - val_accuracy: 0.9504 - val_loss: 0.1592 - learning_rate: 1.0000e-03
# Epoch 10/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9480 - loss: 0.1574 - val_accuracy: 0.9538 - val_loss: 0.1414 - learning_rate: 1.0000e-03
# Epoch 11/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9522 - loss: 0.1428 - val_accuracy: 0.9449 - val_loss: 0.1438 - learning_rate: 1.0000e-03
# Epoch 12/100
# 92/92 - 3s - 31ms/step - accuracy: 0.9553 - loss: 0.1338 - val_accuracy: 0.9558 - val_loss: 0.1358 - learning_rate: 1.0000e-03
# Epoch 13/100
# 92/92 - 3s - 32ms/step - accuracy: 0.9553 - loss: 0.1323 - val_accuracy: 0.9483 - val_loss: 0.1368 - learning_rate: 1.0000e-03
# Epoch 14/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9563 - loss: 0.1290 - val_accuracy: 0.9517 - val_loss: 0.1351 - learning_rate: 1.0000e-03
# Epoch 15/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9534 - loss: 0.1273 - val_accuracy: 0.9490 - val_loss: 0.1337 - learning_rate: 1.0000e-03
# Epoch 16/100
# 92/92 - 3s - 30ms/step - accuracy: 0.9573 - loss: 0.1225 - val_accuracy: 0.9524 - val_loss: 0.1263 - learning_rate: 1.0000e-03
# Epoch 17/100
# 92/92 - 3s - 33ms/step - accuracy: 0.9592 - loss: 0.1218 - val_accuracy: 0.9517 - val_loss: 0.1275 - learning_rate: 1.0000e-03
# Epoch 18/100
# 92/92 - 3s - 30ms/step - accuracy: 0.9570 - loss: 0.1198 - val_accuracy: 0.9524 - val_loss: 0.1220 - learning_rate: 1.0000e-03
# Epoch 19/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9553 - loss: 0.1256 - val_accuracy: 0.9511 - val_loss: 0.1301 - learning_rate: 1.0000e-03
# Epoch 20/100
# 92/92 - 3s - 33ms/step - accuracy: 0.9590 - loss: 0.1264 - val_accuracy: 0.9551 - val_loss: 0.1425 - learning_rate: 1.0000e-03
# Epoch 21/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9556 - loss: 0.1268 - val_accuracy: 0.9558 - val_loss: 0.1189 - learning_rate: 1.0000e-03
# Epoch 22/100
# 92/92 - 3s - 34ms/step - accuracy: 0.9600 - loss: 0.1143 - val_accuracy: 0.9531 - val_loss: 0.1174 - learning_rate: 1.0000e-03
# Epoch 23/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9600 - loss: 0.1136 - val_accuracy: 0.9531 - val_loss: 0.1129 - learning_rate: 1.0000e-03
# Epoch 24/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9638 - loss: 0.1087 - val_accuracy: 0.9558 - val_loss: 0.1156 - learning_rate: 1.0000e-03
# Epoch 25/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9595 - loss: 0.1070 - val_accuracy: 0.9579 - val_loss: 0.1094 - learning_rate: 1.0000e-03
# Epoch 26/100
# 92/92 - 3s - 33ms/step - accuracy: 0.9628 - loss: 0.1081 - val_accuracy: 0.9558 - val_loss: 0.1123 - learning_rate: 1.0000e-03
# Epoch 27/100
# 92/92 - 3s - 32ms/step - accuracy: 0.9583 - loss: 0.1222 - val_accuracy: 0.9545 - val_loss: 0.1262 - learning_rate: 1.0000e-03
# Epoch 28/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9633 - loss: 0.1127 - val_accuracy: 0.9517 - val_loss: 0.1191 - learning_rate: 1.0000e-03
# Epoch 29/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9648 - loss: 0.1020 - val_accuracy: 0.9633 - val_loss: 0.0933 - learning_rate: 1.0000e-03
# Epoch 30/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9657 - loss: 0.0960 - val_accuracy: 0.9606 - val_loss: 0.0967 - learning_rate: 1.0000e-03
# Epoch 31/100
# 92/92 - 3s - 35ms/step - accuracy: 0.9651 - loss: 0.0975 - val_accuracy: 0.9606 - val_loss: 0.1014 - learning_rate: 1.0000e-03
# Epoch 32/100
# 92/92 - 3s - 31ms/step - accuracy: 0.9718 - loss: 0.0923 - val_accuracy: 0.9667 - val_loss: 0.0952 - learning_rate: 1.0000e-03
# Epoch 33/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9677 - loss: 0.0884 - val_accuracy: 0.9687 - val_loss: 0.0862 - learning_rate: 1.0000e-03
# Epoch 34/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9691 - loss: 0.0893 - val_accuracy: 0.9646 - val_loss: 0.0991 - learning_rate: 1.0000e-03
# Epoch 35/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9706 - loss: 0.0854 - val_accuracy: 0.9680 - val_loss: 0.0801 - learning_rate: 1.0000e-03
# Epoch 36/100
# 92/92 - 3s - 33ms/step - accuracy: 0.9743 - loss: 0.0760 - val_accuracy: 0.9701 - val_loss: 0.0848 - learning_rate: 1.0000e-03
# Epoch 37/100
# 92/92 - 3s - 30ms/step - accuracy: 0.9728 - loss: 0.0772 - val_accuracy: 0.9687 - val_loss: 0.0777 - learning_rate: 1.0000e-03
# Epoch 38/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9674 - loss: 0.0989 - val_accuracy: 0.9708 - val_loss: 0.0793 - learning_rate: 1.0000e-03
# Epoch 39/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9760 - loss: 0.0768 - val_accuracy: 0.9687 - val_loss: 0.0886 - learning_rate: 1.0000e-03
# Epoch 40/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9748 - loss: 0.0805 - val_accuracy: 0.9789 - val_loss: 0.0728 - learning_rate: 1.0000e-03
# Epoch 41/100
# 92/92 - 3s - 34ms/step - accuracy: 0.9748 - loss: 0.0753 - val_accuracy: 0.9803 - val_loss: 0.0781 - learning_rate: 1.0000e-03
# Epoch 42/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9786 - loss: 0.0687 - val_accuracy: 0.9742 - val_loss: 0.0695 - learning_rate: 1.0000e-03
# Epoch 43/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9791 - loss: 0.0677 - val_accuracy: 0.9742 - val_loss: 0.0738 - learning_rate: 1.0000e-03
# Epoch 44/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9794 - loss: 0.0708 - val_accuracy: 0.9796 - val_loss: 0.0708 - learning_rate: 1.0000e-03
# Epoch 45/100
# 92/92 - 3s - 33ms/step - accuracy: 0.9833 - loss: 0.0595 - val_accuracy: 0.9694 - val_loss: 0.1103 - learning_rate: 1.0000e-03
# Epoch 46/100
# 92/92 - 3s - 32ms/step - accuracy: 0.9721 - loss: 0.0946 - val_accuracy: 0.9687 - val_loss: 0.0982 - learning_rate: 1.0000e-03
# Epoch 47/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9798 - loss: 0.0763 - val_accuracy: 0.9769 - val_loss: 0.0772 - learning_rate: 1.0000e-03
# Epoch 48/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9855 - loss: 0.0600 - val_accuracy: 0.9803 - val_loss: 0.0698 - learning_rate: 2.0000e-04
# Epoch 49/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9864 - loss: 0.0557 - val_accuracy: 0.9816 - val_loss: 0.0714 - learning_rate: 2.0000e-04
# Epoch 50/100
# 92/92 - 3s - 35ms/step - accuracy: 0.9883 - loss: 0.0541 - val_accuracy: 0.9850 - val_loss: 0.0673 - learning_rate: 2.0000e-04
# Epoch 51/100
# 92/92 - 5s - 51ms/step - accuracy: 0.9889 - loss: 0.0521 - val_accuracy: 0.9844 - val_loss: 0.0647 - learning_rate: 2.0000e-04
# Epoch 52/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9895 - loss: 0.0496 - val_accuracy: 0.9823 - val_loss: 0.0649 - learning_rate: 2.0000e-04
# Epoch 53/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9901 - loss: 0.0464 - val_accuracy: 0.9830 - val_loss: 0.0688 - learning_rate: 2.0000e-04
# Epoch 54/100
# 92/92 - 3s - 32ms/step - accuracy: 0.9884 - loss: 0.0475 - val_accuracy: 0.9823 - val_loss: 0.0654 - learning_rate: 2.0000e-04
# Epoch 55/100
# 92/92 - 3s - 31ms/step - accuracy: 0.9913 - loss: 0.0418 - val_accuracy: 0.9837 - val_loss: 0.0746 - learning_rate: 2.0000e-04
# Epoch 56/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9889 - loss: 0.0425 - val_accuracy: 0.9823 - val_loss: 0.0688 - learning_rate: 2.0000e-04
# Epoch 57/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9927 - loss: 0.0367 - val_accuracy: 0.9837 - val_loss: 0.0634 - learning_rate: 4.0000e-05
# Epoch 58/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9934 - loss: 0.0358 - val_accuracy: 0.9837 - val_loss: 0.0661 - learning_rate: 4.0000e-05
# Epoch 59/100
# 92/92 - 3s - 36ms/step - accuracy: 0.9937 - loss: 0.0360 - val_accuracy: 0.9850 - val_loss: 0.0661 - learning_rate: 4.0000e-05
# Epoch 60/100
# 92/92 - 5s - 49ms/step - accuracy: 0.9939 - loss: 0.0348 - val_accuracy: 0.9850 - val_loss: 0.0658 - learning_rate: 4.0000e-05
# Epoch 61/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9940 - loss: 0.0351 - val_accuracy: 0.9857 - val_loss: 0.0665 - learning_rate: 4.0000e-05
# Epoch 62/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9935 - loss: 0.0344 - val_accuracy: 0.9864 - val_loss: 0.0686 - learning_rate: 4.0000e-05
# Epoch 63/100
# 92/92 - 3s - 36ms/step - accuracy: 0.9954 - loss: 0.0329 - val_accuracy: 0.9864 - val_loss: 0.0684 - learning_rate: 8.0000e-06
# Epoch 64/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9956 - loss: 0.0325 - val_accuracy: 0.9864 - val_loss: 0.0686 - learning_rate: 8.0000e-06
# Epoch 65/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9952 - loss: 0.0324 - val_accuracy: 0.9864 - val_loss: 0.0685 - learning_rate: 8.0000e-06
# Epoch 66/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9944 - loss: 0.0328 - val_accuracy: 0.9864 - val_loss: 0.0685 - learning_rate: 8.0000e-06
# Epoch 67/100
# 92/92 - 3s - 30ms/step - accuracy: 0.9946 - loss: 0.0326 - val_accuracy: 0.9857 - val_loss: 0.0687 - learning_rate: 8.0000e-06
# Epoch 68/100
# 92/92 - 5s - 55ms/step - accuracy: 0.9956 - loss: 0.0330 - val_accuracy: 0.9857 - val_loss: 0.0687 - learning_rate: 1.6000e-06
# Epoch 69/100
# 92/92 - 3s - 29ms/step - accuracy: 0.9944 - loss: 0.0329 - val_accuracy: 0.9857 - val_loss: 0.0686 - learning_rate: 1.6000e-06
# Epoch 70/100
# 92/92 - 3s - 28ms/step - accuracy: 0.9954 - loss: 0.0318 - val_accuracy: 0.9857 - val_loss: 0.0687 - learning_rate: 1.6000e-06
# Epoch 71/100
# 92/92 - 3s - 34ms/step - accuracy: 0.9952 - loss: 0.0332 - val_accuracy: 0.9857 - val_loss: 0.0687 - learning_rate: 1.6000e-06
# Epoch 72/100
# 92/92 - 5s - 51ms/step - accuracy: 0.9939 - loss: 0.0330 - val_accuracy: 0.9857 - val_loss: 0.0687 - learning_rate: 1.6000e-06

# %% [markdown]
# # 4. 결과 분석 및 평가

# %% [markdown]
# ## 4.1 학습 과정 시각화 (Loss & Accuracy)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('GRU Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('GRU Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2 테스트 세트 평가 (Confusion Matrix)

# %%
pred_probs = model_gru.predict(testX_scaled)
pred_classes = np.argmax(pred_probs, axis=-1)

print(f"Accuracy: {accuracy_score(testy, pred_classes):.4f}")
print("\nClassification Report:")
print(classification_report(testy, pred_classes))

cm = confusion_matrix(testy, pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('GRU Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Accuracy: 0.9596
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       496
#            1       1.00      0.98      0.99       471
#            2       0.92      1.00      0.96       420
#            3       0.97      0.86      0.91       491
#            4       0.88      0.98      0.93       532
#            5       1.00      1.00      1.00       537
#
#     accuracy                           0.96      2947
#    macro avg       0.96      0.96      0.96      2947
# weighted avg       0.96      0.96      0.96      2947
